# %%
pip install -qU langchain-groq

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0,
    groq_api_key = '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'
    
    
    
)
response = llm.invoke(" what is modi's full name ...")
print(response)
# Out:
# content="Narendra Modi's full name is Narendra Damodardas Modi." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 43, 'total_tokens': 58, 'completion_time': 0.054545455, 'prompt_time': 0.008083394, 'queue_time': 0.020288426, 'total_time': 0.062628849}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_4e32347616', 'finish_reason': 'stop', 'logprobs': None} id='run-8f1c264b-bd42-4602-a7c5-ceb45da49f09-0' usage_metadata={'input_tokens': 43, 'output_tokens': 15, 'total_tokens': 58}

# %%
pip install -qU langchain_community beautifulsoup4
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://www.hcltech.com/jobs/technical-lead-12")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# Technical lead with Data Fabric-Azure-Azure Data Factory (ADF) in Noida | HCLTech
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Sorry, you need to enable JavaScript to visit this website.
#
#
#
#
#
#
#
#
#
#     Skip to main content
#
#
#
#
#
#
#
#
# HCL Worldwide Navigation
#
#
# Contact Us
#
#
# HCL Worldwide
#
#
#
#
#
#
#                                               Search
#                                             Search Close
#
#
#
# Menu Trigger
#
#
#
#
#
#
#
#
#
# Main Navigation
#
#
# Capabilities
#
#
# HCLTech
#
#
# AI & Generative AI
#
#
# Cloud
#
#
# Engineering
#
#
# Software
#
#
#
#
# HCLTech
#
#
# Application Management
#
#
# Automation
#
#
# Business Process Operations
#
#
# Commercial Apps / SaaS
#
#
# Cybersecurity
#
#
# Data and AI
#
#
# Digital Design and Manufacturing Services
#
#
# Digital Engineering
#
#
# Digital Workplace
#
#
#
#
# HCLTech
#
#
# EdTech
#
#
# Intelligent Operations
#
#
# Internet of Things (IoT)
#
#
# Marketing Services
#
#
# Networks
#
#
# Operational Technology
#
#
# Product Engineering
#
#
# Supply Chain
#
#
# Unified Service Management (USM)
#
#
#
#
#
#
# Industries
#
#
# HCLTech
#
#
# Aerospace and Defense
#
#
# Automotive
#
#
# Consumer Goods
#
#
# Energy and Utilities
#
#
# Global Capability Center
#
#
# Life Sciences and Healthcare
#
#
# Manufacturing
#
#
# Mining and Natural Resources
#
#
#
#
# HCLTech
#
#
# Oil and Gas
#
#
# Public Sector
#
#
# Retail
#
#
# Technology
#
#
# Telecom Media and Entertainment Services
#
#
# Travel, Transport, Logistics & Hospitality
#
#
#
#
# Financial Services
#
#
# Financial Services
#
#
# Financial Services Overview
#
#
# Banking
#
#
# Capital Markets
#
#
# Financial Crime Compliance and Risk
#
#
# Fintech
#
#
# Insurance
#
#
#
#
#
#
# Ecosystem
#
#
# About Us
#
#
# About Us Overview
#
#
# Analyst Recognitions
#
#
# Annual Report 2024
#
#
# Awards and Recognition
#
#
# Code of Business Ethics and Conduct
#
#
# Corporate Social Responsibility
#
#
# Diversity, Equity and Inclusion
#
#
# Global Presence
#
#
# Investor Relations
#
#
# Leadership
#
#
# Newsroom
#
#
# Privacy Trust Center
#
#
# Strategic Alliances
#
#
# Supercharging Progress
#
#
# Sustainability
#
#
# Sustainability Report 2024
#
#
# ABOUT BLANK MENU
#
#
#
#
# Resources
#
#
# Trends and Insights
#
#
# Case Studies
#
#
# Events and Webinars
#
#
#
#
# Careers
#
#
# Careers Overview
#
#
# Careers by LoB
#
#
# Digital Business
#
#
# Digtial Foundation
#
#
# Engineering
#
#
#
#
# Americas
#
#
# Brazil
#
#
# Canada
#
#
# Costa Rica
#
#
# Guatemala
#
#
# Mexico
#
#
# United States
#
#
#
#
# Asia Pacific
#
#
# Australia
#
#
# New Zealand
#
#
# Philippines
#
#
# Sri Lanka
#
#
# Vietnam
#
#
#
#
# Europe
#
#
# Bulgaria
#
#
# Hungary
#
#
# Poland
#
#
# Portugal
#
#
# Romania
#
#
# Spain
#
#
# United Kingdom
#
#
#
#
# India
#
#
# Meet our people
#
#
# Explore job opportunities
#
#
#
#
# Contact Us
#
#
# Our Global Presence
#
#
#
#
#
#
#                                               Search
#                                             Search Close
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Home
#
#
#
#
#
#  ›
#
# Careers
#
#  ›
#
# Careers in India
#
#  ›
#
# Technical lead
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Job Description
#
#
# Technical lead
#
# Job Summary
#
#
#
# Location:
#                 Noida
#
#
#
#
# Project role:
#                 Technical lead
#
#
#
#
# Qualification:
#                 B-Tech
#
#
#
#
# Experience:
#                 7-9 Years
#
#
#
#
# Skills:
#                 Azure Data Factory (ADF)
#
#
# Secondary Skills:
#
#
#                     Python
#
#
#
#
#
# No. of positions:
#                 1
#
#
#
#
# Job description:
#
#               "  Design, develop, deploy, and manage data integration solutions using Azure Data Factory.  Create data pipelines to move and transform data from various sources to target destinations.  Implement data workflows, monitoring, and scheduling using ADF.  Develop and deploy scalable data processing and analytics solutions using Azure Databricks.  Create and optimize Apache Spark jobs for data transformation, machine learning, and big data processing.  Utilize notebooks for data exploration, analysis, and model development.  Implement best practices for performance tuning, reliability, and security in Databricks environments." To be responsible for providing technical guidance or solutions ;define, advocate, and implement best practices and coding standards for the team. To develop and guide the team members in enhancing their  technical  capabilities and increasing productivity To ensure process compliance in the assigned module, and participate in technical discussionsorreview as a technical consultant for feasibility study (technical alternatives, best packages, supporting architecture best practices, technical risks, breakdown into components, estimations). To prepare and submit status reports for minimizing exposure and risks on the project or closure of escalations.
#
#
#
#
#
#
#
#
#
# Apply
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# BT Footer
#
#
# Capabilities
#
#
# Capabilities col 1
#
#
# AI & Generative AI
#
#
# Cloud
#
#
# Engineering
#
#
# Software
#
#
#
#
# Capabilities col 2
#
#
# Application Management
#
#
# Automation
#
#
# Business Process Operations
#
#
# Commercial Apps / SaaS
#
#
# Cybersecurity
#
#
# Data and AI
#
#
# Digital Design and Manufacturing Services
#
#
# Digital Engineering
#
#
# Digital Workplace
#
#
# EdTech
#
#
# Intelligent Operations
#
#
# Internet of Things (IoT)
#
#
# Marketing Services
#
#
# Networks
#
#
# Operational Technology
#
#
# Product Engineering
#
#
# Supply Chain
#
#
# Unified Service Management (USM)
#
#
#
#
#
#
# Industries
#
#
# Aerospace and Defense
#
#
# Automotive
#
#
# Consumer Goods
#
#
# Energy and Utilities
#
#
# Global Capability Center
#
#
# Life Sciences and Healthcare
#
#
# Manufacturing
#
#
# Mining and Natural Resources
#
#
# Oil and Gas
#
#
# Public Sector
#
#
# Retail
#
#
# Technology
#
#
# Telecom Media and Entertainment Services
#
#
# Travel, Transport, Logistics & Hospitality
#
#
# Financial Services
#
#
# Banking
#
#
# Capital Markets
#
#
# Financial Crime Compliance and Risk
#
#
# Fintech
#
#
# Insurance
#
#
#
#
# Columns group 2
#
#
# Ecosystem
#
#
# About Us
#
#
# About Us Overview
#
#
# Analyst Recognitions
#
#
# Annual Report 2024
#
#
# Awards and Recognition
#
#
# Code of Business Ethics and Conduct
#
#
# Corporate Social Responsibility
#
#
# Diversity, Equity and Inclusion
#
#
# Global Presence
#
#
# Investor Relations
#
#
# Leadership
#
#
# Newsroom
#
#
# Privacy Trust Center
#
#
# Strategic Alliances
#
#
# Supercharging Progress
#
#
# Sustainability
#
#
# Sustainability Report 2024
#
#
#
#
# Resources
#
#
# Trends and Insights
#
#
# Case Studies
#
#
# Events and Webinars
#
#
#
#
#
#
# Columns group3
#
#
# Careers
#
#
# Careers Overview
#
#
# Meet our people
#
#
# Explore job opportunities
#
#
# Careers by LoB
#
#
# Digital Business
#
#
# Digtial Foundation
#
#
# Engineering
#
#
#
#
# Americas
#
#
# Brazil
#
#
# Canada
#
#
# Costa Rica
#
#
# Guatemala
#
#
# Mexico
#
#
# United States
#
#
#
#
# Asia Pacific
#
#
# Australia
#
#
# New Zealand
#
#
# Philippines
#
#
# Sri Lanka
#
#
# Vietnam
#
#
#
#
# Europe
#
#
# Bulgaria
#
#
# Hungary
#
#
# Poland
#
#
# Portugal
#
#
# Romania
#
#
# Spain
#
#
# United Kingdom
#
#
#
#
# India
#
#
#
#
# Global Presence
#
#
# Global Presence Overview
#
#
# Americas
#
#
# Brazil
#
#
# Canada
#
#
# Costa Rica
#
#
# Guatemala
#
#
# Mexico
#
#
# United States
#
#
#
#
# EMEA
#
#
# Austria
#
#
# Belgium
#
#
# Bulgaria
#
#
# Czech Republic
#
#
# Denmark
#
#
# Finland
#
#
# France
#
#
# Germany
#
#
# Hungary
#
#
# Ireland
#
#
# Italy
#
#
# Lithuania
#
#
# Luxembourg
#
#
# The Netherlands
#
#
# Norway
#
#
# Poland
#
#
# Portugal
#
#
# Romania
#
#
# Saudi Arabia
#
#
# South Africa
#
#
# Spain
#
#
# Sweden
#
#
# Switzerland
#
#
# UAE
#
#
# United Kingdom
#
#
#
#
# APAC
#
#
# Australia
#
#
# China
#
#
# Hong Kong
#
#
# India
#
#
# Japan
#
#
# Malaysia
#
#
# New Zealand
#
#
# Philippines
#
#
# Singapore
#
#
# South Korea
#
#
# Indonesia
#
#
# Taiwan
#
#
# Thailand
#
#
# Vietnam
#
#
#
#
#
#
#
#
#
#
#
#
# Facebook
# Twitter
# LinkedIn
# Instagram
# Youtube
# Threads
# We use cookies on our site. Please read more about cookies policy here.
#
#
#
#
#
#
# Copyright © 2023 HCL Technologies Limited
#
#
#
#
# Pre footer link
#
#
# Disclaimer
#
#
# Privacy Statement
#
#
# Terms of use
#
#
# Sitemap
#
#
# Raise a Grievance

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
# from langchain_community.document_loaders import WebBaseLoader
# from langchain.prompts import PromptTemplate
# from langchain.chains import LLMChain
# from langchain.llms import OpenAI

# # Step 1: Load the webpage content
# loader = WebBaseLoader("https://www.hcltech.com/jobs/technical-lead-12")
# page_data = loader.load().pop().page_content

# # Step 2: Define the prompt template
# prompt_extract = PromptTemplate(
#     input_variables=["page_data"],
#     template="""
#     ### SCRAPED TEXT FROM WEBSITE:
#     {page_data}
#     ### INSTRUCTION:
#     The scraped text is from the career's page of a website.
#     Your job is to extract the job postings and return them in JSON format containing the 
#     following keys: `role`, `experience`, `skills`, and `description`.
#     Only return the valid JSON.
#     ### VALID JSON (NO PREAMBLE):    
#     """
# )

# llm = ChatGroq(
#     model="llama-3.3-70b-versatile",
#     temperature=0,
#     groq_api_key = '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'
    
    
    
# )


# # Step 4: Create the chain to process the input using the prompt and LLM
# chain_extract = LLMChain(llm=llm, prompt=prompt_extract)

# # Step 5: Pass the scraped page data to the chain
# result = chain_extract.run(page_data=page_data)

# # Output the JSON result
# print(result)
# Out:
# ```json
# {
#   "role": "Technical lead",
#   "experience": "7-9 Years",
#   "skills": ["Azure Data Factory (ADF)", "Python"],
#   "description": "Design, develop, deploy, and manage data integration solutions using Azure Data Factory. Create data pipelines to move and transform data from various sources to target destinations. Implement data workflows, monitoring, and scheduling using ADF. Develop and deploy scalable data processing and analytics solutions using Azure Databricks. Create and optimize Apache Spark jobs for data transformation, machine learning, and big data processing. Utilize notebooks for data exploration, analysis, and model development. Implement best practices for performance tuning, reliability, and security in Databricks environments. To be responsible for providing technical guidance or solutions; define, advocate, and implement best practices and coding standards for the team. To develop and guide the team members in enhancing their technical capabilities and increasing productivity. To ensure process compliance in the assigned module, and participate in technical discussions or review as a technical consultant for feasibility study (technical alternatives, best packages, supporting architecture best practices, technical risks, breakdown into components, estimations). To prepare and submit status reports for minimizing exposure and risks on the project or closure of escalations."
# }
# ```

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Technical lead',
#  'experience': '7-9 Years',
#  'skills': ['Azure Data Factory (ADF)', 'Python'],
#  'description': 'Design, develop, deploy, and manage data integration solutions using Azure Data Factory. Create data pipelines to move and transform data from various sources to target destinations. Implement data workflows, monitoring, and scheduling using ADF. Develop and deploy scalable data processing and analytics solutions using Azure Databricks. Create and optimize Apache Spark jobs for data transformation, machine learning, and big data processing. Utilize notebooks for data exploration, analysis, and model development. Implement best practices for performance tuning, reliability, and security in Databricks environments. To be responsible for providing technical guidance or solutions; define, advocate, and implement best practices and coding standards for the team. To develop and guide the team members in enhancing their technical capabilities and increasing productivity. To ensure process compliance in the assigned module, and participate in technical discussions or review as a technical consultant for feasibility study (technical alternatives, best packages, supporting architecture best practices, technical risks, breakdown into components, estimations). To prepare and submit status reports for minimizing exposure and risks on the project or closure of escalations.'}

# %%
type(json_res)
# Out:
# dict

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# 0                 https://example.com/react-portfolio
# 1               https://example.com/angular-portfolio
# 2                   https://example.com/vue-portfolio
# 3                https://example.com/python-portfolio
# 4                  https://example.com/java-portfolio
# 5               https://example.com/flutter-portfolio
# 6             https://example.com/wordpress-portfolio
# 7               https://example.com/magento-portfolio
# 8          https://example.com/react-native-portfolio
# 9                   https://example.com/ios-portfolio
# 10              https://example.com/android-portfolio
# 11       https://example.com/kotlin-android-portfolio
# 12           https://example.com/android-tv-portfolio
# 13               https://example.com/ios-ar-portfolio
# 14              https://example.com/xamarin-portfolio
# 15       https://example.com/kotlin-backend-portfolio
# 16  https://example.com/typescript-frontend-portfolio
# 17        https://example.com/full-stack-js-portfolio
# 18            https://example.com/ml-python-portfolio
# 19               https://example.com/devops-portfolio

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])
# Out:
# C:\Users\PRETHIVEE RAJAN\.cache\chroma\onnx_models\all-MiniLM-L6-v2\onnx.tar.gz:   1%| | 409k/79.3M [00:05<18:14, 75.6k
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# ~\anaconda\lib\site-packages\httpx\_transports\default.py in map_httpcore_exceptions()
#     100     try:
# --> 101         yield
#     102     except Exception as exc:
#
# ~\anaconda\lib\site-packages\httpx\_transports\default.py in __iter__(self)
#     126         with map_httpcore_exceptions():
# --> 127             for part in self._httpcore_stream:
#     128                 yield part
#
# ~\anaconda\lib\site-packages\httpcore\_sync\connection_pool.py in __iter__(self)
#     406             self.close()
# --> 407             raise exc from None
#     408
#
# ~\anaconda\lib\site-packages\httpcore\_sync\connection_pool.py in __iter__(self)
#     402         try:
# --> 403             for part in self._stream:
#     404                 yield part
#
# ~\anaconda\lib\site-packages\httpcore\_sync\http11.py in __iter__(self)
#     341                 self.close()
# --> 342             raise exc
#     343
#
# ~\anaconda\lib\site-packages\httpcore\_sync\http11.py in __iter__(self)
#     333             with Trace("receive_response_body", logger, self._request, kwargs):
# --> 334                 for chunk in self._connection._receive_response_body(**kwargs):
#     335                     yield chunk
#
# ~\anaconda\lib\site-packages\httpcore\_sync\http11.py in _receive_response_body(self, request)
#     202         while True:
# --> 203             event = self._receive_event(timeout=timeout)
#     204             if isinstance(event, h11.Data):
#
# ~\anaconda\lib\site-packages\httpcore\_sync\http11.py in _receive_event(self, timeout)
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#
# ~\anaconda\lib\site-packages\httpcore\_backends\sync.py in read(self, max_bytes, timeout)
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#
# ~\anaconda\lib\contextlib.py in __exit__(self, typ, value, traceback)
#     136             try:
# --> 137                 self.gen.throw(typ, value, traceback)
#     138             except StopIteration as exc:
#
# ~\anaconda\lib\site-packages\httpcore\_exceptions.py in map_exceptions(map)
#      13             if isinstance(exc, from_exc):
# ---> 14                 raise to_exc(exc) from exc
#      15         raise  # pragma: nocover
#
# ReadError: [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2633)
#
# The above exception was the direct cause of the following exception:
#
# ReadError                                 Traceback (most recent call last)
# ~\anaconda\lib\site-packages\chromadb\api\models\CollectionCommon.py in wrapper(self, *args, **kwargs)
#      89             try:
# ---> 90                 return func(self, *args, **kwargs)
#      91             except Exception as e:
#
# ~\anaconda\lib\site-packages\chromadb\api\models\CollectionCommon.py in _validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     212             validate_record_set_for_embedding(record_set=add_records)
# --> 213             add_embeddings = self._embed_record_set(record_set=add_records)
#     214         else:
#
# ~\anaconda\lib\site-packages\chromadb\api\models\CollectionCommon.py in _embed_record_set(self, record_set, embeddable_fields)
#     525                 else:
# --> 526                     return self._embed(input=record_set[field])  # type: ignore[literal-required]
#     527         raise ValueError(
#
# ~\anaconda\lib\site-packages\chromadb\api\models\CollectionCommon.py in _embed(self, input)
#     538             )
# --> 539         return self._embedding_function(input=input)
#
# ~\anaconda\lib\site-packages\chromadb\api\types.py in __call__(self, input)
#     465         def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 466             result = call(self, input)
#     467             assert result is not None
#
# ~\anaconda\lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py in __call__(self, input)
#     198         # Only download the model when it is actually used
# --> 199         self._download_model_if_not_exists()
#     200         return cast(Embeddings, self._forward(input))
#
# ~\anaconda\lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py in _download_model_if_not_exists(self)
#     225             ):
# --> 226                 self._download(
#     227                     url=self.MODEL_DOWNLOAD_URL,
#
# ~\anaconda\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#
# ~\anaconda\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#
# ~\anaconda\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#
# ~\anaconda\lib\site-packages\tenacity\__init__.py in <lambda>(rs)
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#
# ~\anaconda\lib\concurrent\futures\_base.py in result(self, timeout)
#     438                 elif self._state == FINISHED:
# --> 439                     return self.__get_result()
#     440
#
# ~\anaconda\lib\concurrent\futures\_base.py in __get_result(self)
#     390             try:
# --> 391                 raise self._exception
#     392             finally:
#
# ~\anaconda\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#
# ~\anaconda\lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py in _download(self, url, fname, chunk_size)
#     108             ) as bar:
# --> 109                 for data in resp.iter_bytes(chunk_size=chunk_size):
#     110                     size = file.write(data)
#
# ~\anaconda\lib\site-packages\httpx\_models.py in iter_bytes(self, chunk_size)
#     896             with request_context(request=self._request):
# --> 897                 for raw_bytes in self.iter_raw():
#     898                     decoded = decoder.decode(raw_bytes)
#
# ~\anaconda\lib\site-packages\httpx\_models.py in iter_raw(self, chunk_size)
#     950         with request_context(request=self._request):
# --> 951             for raw_stream_bytes in self.stream:
#     952                 self._num_bytes_downloaded += len(raw_stream_bytes)
#
# ~\anaconda\lib\site-packages\httpx\_client.py in __iter__(self)
#     152     def __iter__(self) -> typing.Iterator[bytes]:
# --> 153         for chunk in self._stream:
#     154             yield chunk
#
# ~\anaconda\lib\site-packages\httpx\_transports\default.py in __iter__(self)
#     127             for part in self._httpcore_stream:
# --> 128                 yield part
#     129
#
# ~\anaconda\lib\contextlib.py in __exit__(self, typ, value, traceback)
#     136             try:
# --> 137                 self.gen.throw(typ, value, traceback)
#     138             except StopIteration as exc:
#
# ~\anaconda\lib\site-packages\httpx\_transports\default.py in map_httpcore_exceptions()
#     117         message = str(exc)
# --> 118         raise mapped_exc(message) from exc
#     119
#
# ReadError: [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2633)
#
# During handling of the above exception, another exception occurred:
#
# ReadError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12788\1927155411.py in <module>
#       7 if not collection.count():
#       8     for _, row in df.iterrows():
# ----> 9         collection.add(documents=row["Techstack"],
#      10                        metadatas={"links": row["Links"]},
#      11                        ids=[str(uuid.uuid4())])
#
# ~\anaconda\lib\site-packages\chromadb\api\models\Collection.py in add(self, ids, embeddings, metadatas, documents, images, uris)
#      80         """
#      81
# ---> 82         add_request = self._validate_and_prepare_add_request(
#      83             ids=ids,
#      84             embeddings=embeddings,
#
# ~\anaconda\lib\site-packages\chromadb\api\models\CollectionCommon.py in wrapper(self, *args, **kwargs)
#      91             except Exception as e:
#      92                 msg = f"{str(e)} in {name}."
# ---> 93                 raise type(e)(msg).with_traceback(e.__traceback__)
#      94
#      95         return wrapper
#
# ~\anaconda\lib\site-packages\chromadb\api\models\CollectionCommon.py in wrapper(self, *args, **kwargs)
#      88         def wrapper(self: Any, *args: Any, **kwargs: Any) -> T:
#      89             try:
# ---> 90                 return func(self, *args, **kwargs)
#      91             except Exception as e:
#      92                 msg = f"{str(e)} in {name}."
#
# ~\anaconda\lib\site-packages\chromadb\api\models\CollectionCommon.py in _validate_and_prepare_add_request(self, ids, embeddings, metadatas, documents, images, uris)
#     211         if add_records["embeddings"] is None:
#     212             validate_record_set_for_embedding(record_set=add_records)
# --> 213             add_embeddings = self._embed_record_set(record_set=add_records)
#     214         else:
#     215             add_embeddings = add_records["embeddings"]
#
# ~\anaconda\lib\site-packages\chromadb\api\models\CollectionCommon.py in _embed_record_set(self, record_set, embeddable_fields)
#     524                     )
#     525                 else:
# --> 526                     return self._embed(input=record_set[field])  # type: ignore[literal-required]
#     527         raise ValueError(
#     528             "Record does not contain any non-None fields that can be embedded."
#
# ~\anaconda\lib\site-packages\chromadb\api\models\CollectionCommon.py in _embed(self, input)
#     537                 "https://docs.trychroma.com/guides/embeddings"
#     538             )
# --> 539         return self._embedding_function(input=input)
#
# ~\anaconda\lib\site-packages\chromadb\api\types.py in __call__(self, input)
#     464
#     465         def __call__(self: EmbeddingFunction[D], input: D) -> Embeddings:
# --> 466             result = call(self, input)
#     467             assert result is not None
#     468             return validate_embeddings(cast(Embeddings, normalize_embeddings(result)))
#
# ~\anaconda\lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py in __call__(self, input)
#     197     def __call__(self, input: Documents) -> Embeddings:
#     198         # Only download the model when it is actually used
# --> 199         self._download_model_if_not_exists()
#     200         return cast(Embeddings, self._forward(input))
#     201
#
# ~\anaconda\lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py in _download_model_if_not_exists(self)
#     224                 self._MODEL_SHA256,
#     225             ):
# --> 226                 self._download(
#     227                     url=self.MODEL_DOWNLOAD_URL,
#     228                     fname=os.path.join(self.DOWNLOAD_PATH, self.ARCHIVE_FILENAME),
#
# ~\anaconda\lib\site-packages\tenacity\__init__.py in wrapped_f(*args, **kw)
#     334             copy = self.copy()
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#     338         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# ~\anaconda\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     473         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
#
# ~\anaconda\lib\site-packages\tenacity\__init__.py in iter(self, retry_state)
#     374         result = None
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#     378
#
# ~\anaconda\lib\site-packages\tenacity\__init__.py in <lambda>(rs)
#     396     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#     400
#
# ~\anaconda\lib\concurrent\futures\_base.py in result(self, timeout)
#     437                     raise CancelledError()
#     438                 elif self._state == FINISHED:
# --> 439                     return self.__get_result()
#     440
#     441                 self._condition.wait(timeout)
#
# ~\anaconda\lib\concurrent\futures\_base.py in __get_result(self)
#     389         if self._exception:
#     390             try:
# --> 391                 raise self._exception
#     392             finally:
#     393                 # Break a reference cycle with the exception in self._exception
#
# ~\anaconda\lib\site-packages\tenacity\__init__.py in __call__(self, fn, *args, **kwargs)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#     480                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# ~\anaconda\lib\site-packages\chromadb\utils\embedding_functions\onnx_mini_lm_l6_v2.py in _download(self, url, fname, chunk_size)
#     107                 unit_divisor=1024,
#     108             ) as bar:
# --> 109                 for data in resp.iter_bytes(chunk_size=chunk_size):
#     110                     size = file.write(data)
#     111                     bar.update(size)
#
# ~\anaconda\lib\site-packages\httpx\_models.py in iter_bytes(self, chunk_size)
#     895             chunker = ByteChunker(chunk_size=chunk_size)
#     896             with request_context(request=self._request):
# --> 897                 for raw_bytes in self.iter_raw():
#     898                     decoded = decoder.decode(raw_bytes)
#     899                     for chunk in chunker.decode(decoded):
#
# ~\anaconda\lib\site-packages\httpx\_models.py in iter_raw(self, chunk_size)
#     949
#     950         with request_context(request=self._request):
# --> 951             for raw_stream_bytes in self.stream:
#     952                 self._num_bytes_downloaded += len(raw_stream_bytes)
#     953                 for chunk in chunker.decode(raw_stream_bytes):
#
# ~\anaconda\lib\site-packages\httpx\_client.py in __iter__(self)
#     151
#     152     def __iter__(self) -> typing.Iterator[bytes]:
# --> 153         for chunk in self._stream:
#     154             yield chunk
#     155
#
# ~\anaconda\lib\site-packages\httpx\_transports\default.py in __iter__(self)
#     126         with map_httpcore_exceptions():
#     127             for part in self._httpcore_stream:
# --> 128                 yield part
#     129
#     130     def close(self) -> None:
#
# ~\anaconda\lib\contextlib.py in __exit__(self, typ, value, traceback)
#     135                 value = typ()
#     136             try:
# --> 137                 self.gen.throw(typ, value, traceback)
#     138             except StopIteration as exc:
#     139                 # Suppress StopIteration *unless* it's the same exception that
#
# ~\anaconda\lib\site-packages\httpx\_transports\default.py in map_httpcore_exceptions()
#     116
#     117         message = str(exc)
# --> 118         raise mapped_exc(message) from exc
#     119
#     120
#
# ReadError: [SSL: DECRYPTION_FAILED_OR_BAD_RECORD_MAC] decryption failed or bad record mac (_ssl.c:2633) in add.
