# %%
pip install -qU langchain-groq

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(
    model="llama-3.3-70b-versatile",
    temperature=0,
    groq_api_key = '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'
    
    
    
)
response = llm.invoke(" what is modi's full name ...")
print(response)
# Out:
# content="Narendra Modi's full name is Narendra Damodardas Modi." additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 15, 'prompt_tokens': 43, 'total_tokens': 58, 'completion_time': 0.072045854, 'prompt_time': 0.011513844, 'queue_time': 0.018007804000000002, 'total_time': 0.083559698}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_c0cfa69934', 'finish_reason': 'stop', 'logprobs': None} id='run-23f2bfed-9349-4db5-94e9-3fb9e50d740d-0' usage_metadata={'input_tokens': 43, 'output_tokens': 15, 'total_tokens': 58}

# %%
pip install -qU langchain_community beautifulsoup4
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from langchain_community.document_loaders import WebBaseLoader

loader = WebBaseLoader("https://www.hcltech.com/jobs/technical-lead-12")
page_data = loader.load().pop().page_content
print(page_data)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# Technical lead with Data Fabric-Azure-Azure Data Factory (ADF) in Noida | HCLTech
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#           Sorry, you need to enable JavaScript to visit this website.
#
#
#
#
#
#
#
#
#
#     Skip to main content
#
#
#
#
#
#
#
#
# HCL Worldwide Navigation
#
#
# Contact Us
#
#
# HCL Worldwide
#
#
#
#
#
#
#                                               Search
#                                             Search Close
#
#
#
# Menu Trigger
#
#
#
#
#
#
#
#
#
# Main Navigation
#
#
# Capabilities
#
#
# HCLTech
#
#
# AI & Generative AI
#
#
# Cloud
#
#
# Engineering
#
#
# Software
#
#
#
#
# HCLTech
#
#
# Application Management
#
#
# Automation
#
#
# Business Process Operations
#
#
# Commercial Apps / SaaS
#
#
# Cybersecurity
#
#
# Data and AI
#
#
# Digital Design and Manufacturing Services
#
#
# Digital Engineering
#
#
# Digital Workplace
#
#
#
#
# HCLTech
#
#
# EdTech
#
#
# ...

# %%
from langchain_core.prompts import PromptTemplate

prompt_extract = PromptTemplate.from_template(
        """
        ### SCRAPED TEXT FROM WEBSITE:
        {page_data}
        ### INSTRUCTION:
        The scraped text is from the career's page of a website.
        Your job is to extract the job postings and return them in JSON format containing the 
        following keys: `role`, `experience`, `skills` and `description`.
        Only return the valid JSON.
        ### VALID JSON (NO PREAMBLE):    
        """
)

chain_extract = prompt_extract | llm 
res = chain_extract.invoke(input={'page_data':page_data})
type(res.content)
# Out:
# str

# %%
# from langchain_community.document_loaders import WebBaseLoader
# from langchain.prompts import PromptTemplate
# from langchain.chains import LLMChain
# from langchain.llms import OpenAI

# # Step 1: Load the webpage content
# loader = WebBaseLoader("https://www.hcltech.com/jobs/technical-lead-12")
# page_data = loader.load().pop().page_content

# # Step 2: Define the prompt template
# prompt_extract = PromptTemplate(
#     input_variables=["page_data"],
#     template="""
#     ### SCRAPED TEXT FROM WEBSITE:
#     {page_data}
#     ### INSTRUCTION:
#     The scraped text is from the career's page of a website.
#     Your job is to extract the job postings and return them in JSON format containing the 
#     following keys: `role`, `experience`, `skills`, and `description`.
#     Only return the valid JSON.
#     ### VALID JSON (NO PREAMBLE):    
#     """
# )

# llm = ChatGroq(
#     model="llama-3.3-70b-versatile",
#     temperature=0,
#     groq_api_key = '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'
    
    
    
# )


# # Step 4: Create the chain to process the input using the prompt and LLM
# chain_extract = LLMChain(llm=llm, prompt=prompt_extract)

# # Step 5: Pass the scraped page data to the chain
# result = chain_extract.run(page_data=page_data)

# # Output the JSON result
# print(result)
# Out:
# ```json
# {
#   "role": "Technical lead",
#   "experience": "7-9 Years",
#   "skills": ["Azure Data Factory (ADF)", "Python"],
# ...

# %%
from langchain_core.output_parsers import JsonOutputParser

json_parser = JsonOutputParser()
json_res = json_parser.parse(res.content)
json_res
# Out:
# {'role': 'Technical lead',
#  'experience': '7-9 Years',
#  'skills': ['Azure Data Factory (ADF)', 'Python'],
# ...

# %%
type(json_res)
# Out:
# dict

# %%
import pandas as pd

df = pd.read_csv("my_portfolio.csv")
df
# Out:
#                                Techstack  \
# 0                React, Node.js, MongoDB
# 1               Angular,.NET, SQL Server
# 2      Vue.js, Ruby on Rails, PostgreSQL
# 3                  Python, Django, MySQL
# 4              Java, Spring Boot, Oracle
# 5             Flutter, Firebase, GraphQL
# 6                  WordPress, PHP, MySQL
# 7                    Magento, PHP, MySQL
# 8         React Native, Node.js, MongoDB
# 9                  iOS, Swift, Core Data
# 10       Android, Java, Room Persistence
# 11             Kotlin, Android, Firebase
# 12       Android TV, Kotlin, Android NDK
# 13                     iOS, Swift, ARKit
# 14        Cross-platform, Xamarin, Azure
# 15          Backend, Kotlin, Spring Boot
# 16         Frontend, TypeScript, Angular
# 17    Full-stack, JavaScript, Express.js
# 18  Machine Learning, Python, TensorFlow
# 19               DevOps, Jenkins, Docker
#
#                                                 Links
# ...

# %%
import uuid
import chromadb

client = chromadb.PersistentClient('vectorstore')
collection = client.get_or_create_collection(name="portfolio")

if not collection.count():
    for _, row in df.iterrows():
        collection.add(documents=row["Techstack"],
                       metadatas={"links": row["Links"]},
                       ids=[str(uuid.uuid4())])

# %%
job = json_res
job['skills']
# Out:
# ['Azure Data Factory (ADF)', 'Python']

# %%
links = collection.query(query_texts=job['skills'], n_results=2).get('metadatas', [])
links


# links = collection.query(query_texts=["experience in python","expert in react"], n_results=2).get('metadatas', [])
# links
# Out:
# [[{'links': 'https://example.com/xamarin-portfolio'},
#   {'links': 'https://example.com/angular-portfolio'}],
#  [{'links': 'https://example.com/ml-python-portfolio'},
#   {'links': 'https://example.com/python-portfolio'}]]

# %%
job
# Out:
# {'role': 'Technical lead',
#  'experience': '7-9 Years',
#  'skills': ['Azure Data Factory (ADF)', 'Python'],
# ...

# %%
prompt_email = PromptTemplate.from_template(
        """
        ### JOB DESCRIPTION:
        {job_description}
        
        ### INSTRUCTION:
        You are Prethivee, a business development executive at Hero_Q. Hero_Q is an AI & Software Consulting company dedicated to facilitating
        the seamless integration of business processes through automated tools. 
        Over our experience, we have empowered numerous enterprises with tailored solutions, fostering scalability, 
        process optimization, cost reduction, and heightened overall efficiency. 
        Your job is to write a cold email to the client regarding the job mentioned above describing the capability of AtliQ 
        in fulfilling their needs.
        Also add the most relevant ones from the following links to showcase Hero_Q's portfolio: {link_list}
        Remember you are Prethivee, BDE at Hero_Q. 
        Do not provide a preamble.
        ### EMAIL (NO PREAMBLE):
        
        """
        )

chain_email = prompt_email | llm
res = chain_email.invoke({"job_description": str(job), "link_list": links})
print(res.content)
# Out:
# Subject: Expert Technical Lead Services for Azure Data Factory and Python
#
# Dear Hiring Manager,
#
# I came across your job description for a Technical Lead with expertise in Azure Data Factory (ADF) and Python. I'd like to introduce you to Hero_Q, a renowned AI & Software Consulting company that can fulfill your requirements.
#
# Our team at Hero_Q has extensive experience in designing, developing, deploying, and managing data integration solutions using Azure Data Factory. We can create data pipelines to move and transform data from various sources to target destinations, implement data workflows, monitoring, and scheduling using ADF. Additionally, we can develop and deploy scalable data processing and analytics solutions using Azure Databricks, creating and optimizing Apache Spark jobs for data transformation, machine learning, and big data processing.
#
# ...
